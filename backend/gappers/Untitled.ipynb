# %%
! google-chrome -product-version
# Out:
# /bin/bash: google-chrome: command not found

# %%
from common.utils import ghost_driver, wait_random_seconds
from gappers.tasks import (get_benzinga_premerket_tickers, scrape_stocks_statistics_barchart, parse_gappers_barchart_and_filter, parse_stock_statistics_yquery)

# %%
from news.tasks import stockNewsApi_get_resent_news, scrape_finviz_news

# %%
driver = ghost_driver()

# %%
stoncks = get_benzinga_premerket_tickers(driver)
# Out:
# SHC
# PBLA
# PRE
# VYNE
# DATS
# OSH
# WEJO
# HPCO
# REVBU
# FRO
# JSPR
# QLGN
# XOS
# JAN
# VS
# MATH
# NUWE
# BIOR
# CVAC
# SNGX

# %%
today = timezone.now()

# %%
stocks = UpGapper.objects.filter(date__day=today.day, date__month=today.month, date__year=today.year)

# %%
scrape_stocks_statistics_barchart(driver, stocks)
# Out:
# SHC
# Waiting 3 Seconds...
# PBLA
# Waiting 4 Seconds...
# PRE
# Waiting 5 Seconds...
# VYNE
# Waiting 5 Seconds...
# DATS
# Waiting 3 Seconds...
# OSH
# Waiting 5 Seconds...
# WEJO
# Waiting 4 Seconds...
# FRO
# Waiting 5 Seconds...
# JSPR
# Waiting 3 Seconds...
# QLGN
# Waiting 3 Seconds...
# XOS
# Waiting 4 Seconds...
# JAN
# Waiting 5 Seconds...
# VS
# Waiting 3 Seconds...
# NUWE
# Waiting 3 Seconds...
# BIOR
# Waiting 5 Seconds...
# CVAC
# Waiting 4 Seconds...
# ...

# %%
parse_gappers_barchart_and_filter()
# Out:
# [<UpGapper: 2023-01-11 PKBO 0.4993 52000>,
#  <UpGapper: 2023-01-11 CLLS 0.1026 517300>,
#  <UpGapper: 2023-01-11 PSMT 0.0705 157900>,
#  <UpGapper: 2023-01-11 ACCD 0.0576 3185600>,
#  <UpGapper: 2023-01-11 AMPS 0.0546 1525500>]

# %%
stocks = UpGapper.objects.filter(date__day=today.day, date__month=today.month, date__year=today.year)

# %%
stocks
# Out:
# <QuerySet [<UpGapper: 2023-01-11 PBLA 0.7185000000 31020000>, <UpGapper: 2023-01-11 SHC 0.7005000000 49454102>, <UpGapper: 2023-01-11 PRE 0.6021000000 42998504>, <UpGapper: 2023-01-11 VYNE 0.5682000000 5280000>, <UpGapper: 2023-01-11 PKBO 0.4993000000 52000>, <UpGapper: 2023-01-11 DATS 0.3491000000 2520000>, <UpGapper: 2023-01-11 OSH 0.3091000000 15032000>, <UpGapper: 2023-01-11 WEJO 0.2951000000 238870>, <UpGapper: 2023-01-11 JSPR 0.2389000000 4870000>, <UpGapper: 2023-01-11 FRO 0.2143000000 33598700>, <UpGapper: 2023-01-11 QLGN 0.2046000000 2320000>, <UpGapper: 2023-01-11 XOS 0.1933000000 111370>, <UpGapper: 2023-01-11 JAN 0.1917000000 1400000>, <UpGapper: 2023-01-11 VS 0.1706000000 1670000>, <UpGapper: 2023-01-11 NUWE 0.1423000000 1420900>, <UpGapper: 2023-01-11 CLLS 0.1026000000 517300>, <UpGapper: 2023-01-11 BIOR 0.0711000000 55630102>, <UpGapper: 2023-01-11 PSMT 0.0705000000 157900>, <UpGapper: 2023-01-11 CVAC 0.0673000000 5607900>, <UpGapper: 2023-01-11 ACCD 0.0576000000 31856
# ...

# %%
parse_stock_statistics_yquery(stocks)
# Out:
# yahooquery  PBLA Panbela Therapeutics
# Waiting 3 Seconds...
# Waiting 2 Seconds...
# yahooquery  SHC Sotera Health Company
# Waiting 3 Seconds...
# Waiting 1 Seconds...
# yahooquery  PRE Prenetics Global Limited Class A Ordinary Share
# Waiting 3 Seconds...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-0f8df9beaf7c> in <module>
# ----> 1 parse_stock_statistics_yquery(stocks)
#
# /backend/gappers/tasks.py in parse_stock_statistics_yquery(stocks)
#     219     for stock in stocks:
#     220         print('yahooquery ', stock.ticker, stock.company_name)
# --> 221         wait_random_seconds(min=1, max=3)
#     222         data = Ticker(stock.ticker).get_modules(['quoteType', 'defaultKeyStatistics', 'summaryDetail'])
#     223         # print(data)
#
# /backend/common/utils.py in wait_random_seconds(min, max)
# ...

# %%
# %env TOKEN_API_stockNewsApi=frc2vflvcruvmeqfrj3i09wdf4ob0dfvtpcvqdll
# Out:
# env: TOKEN_API_stockNewsApi=frc2vflvcruvmeqfrj3i09wdf4ob0dfvtpcvqdll

# %%
! printenv
# Out:
# SECRET_DB_PASSWORD=Host557gah6Ghs*Ysds
# MPLBACKEND=module://ipykernel.pylab.backend_inline
# HOSTNAME=2d6491e4f89e
# SECRET_KEY=rco8wm!k^5gw2tq4qp4f0oyvu-wo85pl0k7@cdp-=y6rbmie3=
# JUPYTER_TOKEN=eaEahuHUeaEahuHU
# SECRET_DB_HOST=db
# HOME=/root
# RABBITMQ_DEFAULT_USER=rabbitadmin
# SECRET_DB_USER=varveler
# PAGER=cat
# APCA_API_KEY_ID=3d823204675d39ff681342a19b3635159f666adb
# APCA_API_SECRET_KEY=3d823204675d39ff681342a19b3635159f666adb
# RABBIT_ENV_RABBITMQ_PASS=rabbit4556ADMIN
# SECRET_DB_PORT=5432
# SECRET_DB_NAME=realedge
# TERM=xterm-color
# DJANGO_ALLOW_ASYNC_UNSAFE=true
# PATH=/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin
# DJANGO_SETTINGS_MODULE=backend.settings.development
# TOKEN_API_stockNewsApi=frc2vflvcruvmeqfrj3i09wdf4ob0dfvtpcvqdll
# GIT_PAGER=cat
# RABBIT_ENV_USER=rabbitadmin
# CLICOLOR=1
# PWD=/backend/gappers
# JPY_PARENT_PID=7
# PYTHONPATH=/backend
# TZ=US/Eastern
# RABBITMQ_DEFAULT_PASS=rabbit4556ADMIN

# %%
for s in stocks:
    stockNewsApi_get_resent_news(s.ticker, s.id)

# %%
import requests

# %%
url = 'https://stocknewsapi.com/api/v1?tickers={ticker}&items=10&token={token}'.format(ticker = 'PBLA', token = 'frc2vflvcruvmeqfrj3i09wdf4ob0dfvtpcvqdll')

# %%
url
# Out:
# 'https://stocknewsapi.com/api/v1?tickers=PBLA&items=10&token=frc2vflvcruvmeqfrj3i09wdf4ob0dfvtpcvqdll'

# %%
response = requests.get(url)

# %%
stocks
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c19aac9f4130> in <module>
# ----> 1 stocks
#
# NameError: name 'stocks' is not defined

# %%
for s in stocks:
    scrape_finviz_news(driver, s.ticker, s.id)
    wait_random_seconds()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-49-ed1b43859818> in <module>
#       1 for s in stocks:
# ----> 2     scrape_finviz_news(driver, s.ticker, s.id)
#       3     wait_random_seconds()
#
# /usr/local/lib/python3.6/dist-packages/celery/local.py in __call__(self, *a, **kw)
#     186
#     187     def __call__(self, *a, **kw):
# --> 188         return self._get_current_object()(*a, **kw)
#     189
#     190     def __len__(self):
#
# /usr/local/lib/python3.6/dist-packages/celery/app/task.py in __call__(self, *args, **kwargs)
#     386         self.push_request(args=args, kwargs=kwargs)
#     387         try:
# --> 388             return self.run(*args, **kwargs)
#     389         finally:
#     390             self.pop_request()
#
# /backend/news/tasks.py in scrape_finviz_news(driver, ticker, up_gapper_id)
#      57     no_news_found = False
# ...

# %%
driver
# Out:
# <selenium.webdriver.remote.webdriver.WebDriver (session="8ece7fce62e2d484df85a09112b94d26")>

# %%
url = 'https://finviz.com/quote.ashx?t=PBLA&p=d'

# %%
driver.get(url)

# %%
driver.execute_script("window.open('');")
# Out:
# ---------------------------------------------------------------------------
# InvalidSessionIdException                 Traceback (most recent call last)
# <ipython-input-47-12fdc787cc16> in <module>
# ----> 1 driver.execute_script("window.open('');")
#
# /usr/local/lib/python3.6/dist-packages/selenium/webdriver/remote/webdriver.py in execute_script(self, script, *args)
#     634         return self.execute(command, {
#     635             'script': script,
# --> 636             'args': converted_args})['value']
#     637
#     638     def execute_async_script(self, script, *args):
#
# /usr/local/lib/python3.6/dist-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
# ...

# %%
driver = ghost_driver()

# %%
driver.get(url)

# %%
for s in stocks:
    print(s.ticker)
    scrape_finviz_news(driver, s.ticker, s.id)
    wait_random_seconds()
# Out:
# PBLA
# Waiting 4 Seconds...
# SHC
# Waiting 3 Seconds...
# PRE
# Waiting 2 Seconds...
# VYNE
# Waiting 3 Seconds...
# PKBO
# Waiting 4 Seconds...
# DATS
# Waiting 4 Seconds...
# OSH
# Waiting 4 Seconds...
# WEJO
# Waiting 2 Seconds...
# JSPR
# Waiting 2 Seconds...
# FRO
# Waiting 2 Seconds...
# QLGN
# Waiting 2 Seconds...
# XOS
# Waiting 3 Seconds...
# JAN
# Waiting 4 Seconds...
# VS
# Waiting 4 Seconds...
# NUWE
# Waiting 4 Seconds...
# CLLS
# Waiting 3 Seconds...
# BIOR
# Waiting 2 Seconds...
# PSMT
# Waiting 2 Seconds...
# CVAC
# Waiting 3 Seconds...
# ACCD
# Waiting 4 Seconds...
# AMPS
